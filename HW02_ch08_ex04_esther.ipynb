# %%
# The following functions are all intended to check whether a string contains
# any lowercase letters, but at least some of them are wrong. For each
# function, describe (is the docstring) what the function actually does.
# You can assume that the parameter is a string.

# Do not merely paste the output as a counterexample into the documentation
# string, explain what is wrong.


###############################################################################
# Body


def any_lowercase1(s):
    """This function only checks if the first letter of the word is in lower case.
        If the second letter in the word is upper case, this function won't detect.
    """
    for c in s:
        if c.islower():
            return True
        else:
            return False


def any_lowercase2(s):
    """This function always return "True" because it only checks if the letter 'c' is lower case.
    """
    for c in s:
        if 'c'.islower():
            return 'True'
        else:
            return 'False'


def any_lowercase3(s):
    """This function only check if the last letter of a word is lower case.
    """
    for c in s:
        flag = c.islower()
    return flag


def any_lowercase4(s):
    """This function works perfectly to find if there is any lower case letter. 
        When detected a lower case, the flag will change to "True".
    """
    flag = False
    for c in s:
        flag = flag or c.islower()
    return flag


def any_lowercase5(s):
    """This works to find if there is any upper case letter.
        When detected an Upper case, it will return "False".
    """
    for c in s:
        if not c.islower():
            return False
    return True


###############################################################################
def main():

    # Remove print("Hello World!") and for each function above that is wrong,
    # call that function with a string for which the function returns
    # incorrectly.
    # ex.: any_lowercase_("thisstringmessesupthefunction")
    print(any_lowercase1('bAnana'))
    print(any_lowercase2('Candy'))
    print(any_lowercase3('BANANa'))
    print(any_lowercase4('tO'))
    print(any_lowercase5('tO'))

if __name__ == '__main__':
    main()
# Out:
# True
# True
# True
# True
# False
